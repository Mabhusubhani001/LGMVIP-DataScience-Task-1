# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Read the image in RGB format
image = cv2.imread('test1.jpg', cv2.IMREAD_COLOR)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert the image to grayscale
gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# Invert the grayscale image
inverted = cv2.bitwise_not(gray)

# Blur the inverted image
blur = cv2.GaussianBlur(inverted, (21, 21), 0)

# Divide the grayscale image by the inverted blurry image
sketch = cv2.divide(gray, blur, scale=256.0)

# Display the sketch
cv2_imshow( image)
cv2_imshow(sketch)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=544x544 at 0x797DA2867700>
# <PIL.Image.Image image mode=L size=544x544 at 0x797DD61F42E0>

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)
